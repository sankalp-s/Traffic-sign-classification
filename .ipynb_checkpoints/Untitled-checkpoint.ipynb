# %%
import pandas as pd

# %%
read_file = pd.read_csv(r'C:\\Users\\Sankalp Arora\\Desktop\\data_smart .csv')

# %%
print(read_file)
# Out:
#      Portuguese Public Administration - Fundamentals and Models  \
# 0                                               Algebra
# 1                                        Linear algebra
# 2                Linear Algebra and Analytical Geometry
# 3                          Algorithms Computer Graphics
# 4                           Algorithms and Complexidade
# ...                                                 ...
# 2429                                 Process Connection
# 2430                        Project construction Welded
# 2431                         Welding Process Simulation
# 2432                                            #VALUE!
# 2433                                            #VALUE!
#
#       Aveiro University  \
# 0     Aveiro University
# 1     Aveiro University
# 2     Aveiro University
# 3     Aveiro University
# 4     Aveiro University
# ...                 ...
# 2429  Aveiro University
# 2430  Aveiro University
# 2431  Aveiro University
# 2432            #VALUE!
# ...

# %%
read_file.dropna()
# Out:
#      Portuguese Public Administration - Fundamentals and Models  \
# 1745                                          materials
# 1863                                          Education
# 2369                                         Management
#
#                            Aveiro University  \
# 1745  Technologies and Manufacturing Process
# 1863                             Mathematics
# 2369                                 Tourism
#
# ...

# %%
read_file.to_csv('C:\\Users\\Sankalp Arora\\Desktop\\removed.csv', index = None, header=True)
